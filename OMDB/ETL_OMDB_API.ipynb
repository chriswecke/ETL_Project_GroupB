# %%
import requests
import json
import pandas as pd
from config import api_key
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
from pprint import pprint

# %%
tom_hanks_df = pd.read_csv ('../TMDB/Movie_Credits.csv')
tom_hanks_df
# Out:
#      Unnamed: 0                            character  \
# 0             0                         Forrest Gump
# 1             1                        Paul Edgecomb
# 2             2                           Jim Lovell
# 3             3                       Robert Langdon
# 4             4                      Viktor Navorski
# ..          ...                                  ...
# 116         116                                  NaN
# 117         117            Himself (archive footage)
# 118         118  Self (archive footage) (uncredited)
# 119         119                       Himself - Host
# 120         120                              (voice)
#
#                     credit_id                       poster_path      id  \
# 0    52fe420ec3a36847f800074f  /clolk7rB5lAjs41SD0Vt6IXYLMm.jpg      13
# 1    52fe424ac3a36847f8012bc7  /velWPhVMQeQKcxggNEU8YmIo52R.jpg     497
# 2    52fe4253c3a36847f801595d  /oYUZHYMwNKnE1ef4WE5Hw2a9OAY.jpg     568
# ...

# %%
titles=tom_hanks_df['title'].tolist()
titles
# Out:
# ['Forrest Gump',
#  'The Green Mile',
#  'Apollo 13',
#  'The Da Vinci Code',
#  'The Terminal',
#  'Saving Private Ryan',
#  'Sleepless in Seattle',
#  'Toy Story',
#  'Toy Story 3',
#  'Big',
#  'Joe Versus the Volcano',
#  'Splash',
#  'The Money Pit',
#  'Road to Perdition',
#  'The Man with One Red Shoe',
#  'Magnificent Desolation: Walking on the Moon',
#  'The Ladykillers',
#  'Shooting War',
#  'A League of Their Own',
#  "Charlie Wilson's War",
#  'Turner & Hooch',
#  'Cast Away',
#  "The 'Burbs",
#  'Bachelor Party',
#  "You've Got Mail",
#  'The Bonfire of the Vanities',
#  'Philadelphia',
#  'Mazes and Monsters',
#  'Angels & Demons',
#  'Every Time We Say Goodbye',
#  'Nothing in Common',
#  'Volunteers',
#  'Small Fry',
#  'Hawaiian Vacation',
#  'Larry Crowne',
#  'Captain Phillips',
#  'Killing Lincoln',
#  'Cloud Atlas',
#  'Bridge of Spies',
#  'Inferno',
#  'A Hologram for the King',
#  'Sully',
#  'Toy Story 4',
#  'The Polar Express',
# ...

# %%
url = "http://www.omdbapi.com/?apikey=" + api_key + "&t="
movies = titles
responses = []
for movie in movies:
    movie_data = requests.get(url + movie).json()
    responses.append(movie_data)

# %%
responses
# Out:
# [{'Title': 'Forrest Gump',
#   'Year': '1994',
#   'Rated': 'PG-13',
#   'Released': '06 Jul 1994',
#   'Runtime': '142 min',
#   'Genre': 'Drama, Romance',
#   'Director': 'Robert Zemeckis',
#   'Writer': 'Winston Groom (novel), Eric Roth (screenplay)',
#   'Actors': 'Tom Hanks, Rebecca Williams, Sally Field, Michael Conner Humphreys',
#   'Plot': 'The presidencies of Kennedy and Johnson, the events of Vietnam, Watergate and other historical events unfold through the perspective of an Alabama man with an IQ of 75, whose only desire is to be reunited with his childhood sweetheart.',
#   'Language': 'English',
#   'Country': 'USA',
#   'Awards': 'Won 6 Oscars. Another 44 wins & 75 nominations.',
#   'Poster': 'https://m.media-amazon.com/images/M/MV5BNWIwODRlZTUtY2U3ZS00Yzg1LWJhNzYtMmZiYmEyNmU1NjMzXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#   'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'},
#    {'Source': 'Rotten Tomatoes', 'Value': '71%'},
# ...

# %%
hanks_movies=pd.DataFrame(responses)

# %%
hanks_movies
# Out:
#                                                Title  Year  Rated  \
# 0                                       Forrest Gump  1994  PG-13
# 1                                     The Green Mile  1999      R
# 2                                          Apollo 13  1995     PG
# 3                                  The Da Vinci Code  2006  PG-13
# 4                                       The Terminal  2004  PG-13
# ..                                               ...   ...    ...
# 116                 The Rutles 2: Can't Buy Me Lunch  2004  PG-13
# 117  Beyond Boundaries: The Harvey Weinstein Scandal  2018  TV-14
# 118                                        The Queen  2006  PG-13
# 119                                              NaN   NaN    NaN
# 120                                     Transformers  2007  PG-13
#
#         Released  Runtime                           Genre  \
# 0    06 Jul 1994  142 min                  Drama, Romance
# ...

# %%
for col in hanks_movies.columns: 
    print(col)

# %%
hanks2 = hanks_movies.drop(columns=['Website','DVD','Error','totalSeasons', 'Poster','Response','BoxOffice'])
hanks2
# Out:
#                                                Title  Year  Rated  \
# 0                                       Forrest Gump  1994  PG-13
# 1                                     The Green Mile  1999      R
# 2                                          Apollo 13  1995     PG
# 3                                  The Da Vinci Code  2006  PG-13
# 4                                       The Terminal  2004  PG-13
# ..                                               ...   ...    ...
# 116                 The Rutles 2: Can't Buy Me Lunch  2004  PG-13
# 117  Beyond Boundaries: The Harvey Weinstein Scandal  2018  TV-14
# 118                                        The Queen  2006  PG-13
# 119                                              NaN   NaN    NaN
# 120                                     Transformers  2007  PG-13
#
#         Released  Runtime                           Genre  \
# 0    06 Jul 1994  142 min                  Drama, Romance
# ...

# %%
for col in tom_hanks_df.columns: 
    print(col)
# Out:
# Unnamed: 0
# character
# credit_id
# poster_path
# id
# video
# vote_count
# adult
# backdrop_path
# genre_ids
# original_language
# original_title
# popularity
# title
# vote_average
# overview
# release_date

# %%
hanks3 = tom_hanks_df.drop(columns=['Unnamed: 0','poster_path','adult','original_language', 'original_title','release_date'])
hanks3
# Out:
#                                character                 credit_id      id  \
# 0                           Forrest Gump  52fe420ec3a36847f800074f      13
# 1                          Paul Edgecomb  52fe424ac3a36847f8012bc7     497
# 2                             Jim Lovell  52fe4253c3a36847f801595d     568
# 3                         Robert Langdon  52fe4259c3a36847f8017445     591
# 4                        Viktor Navorski  52fe4259c3a36847f801762f     594
# ..                                   ...                       ...     ...
# 116                                  NaN  59e392f79251410b670002c4   32694
# 117            Himself (archive footage)  5dd3b664356a715875e9eed6  558912
# 118  Self (archive footage) (uncredited)  5f5aa8efec0c580038a462e8    1165
# 119                       Himself - Host  5cb28f639251411ed620788c   31107
# 120                              (voice)  5f7cd9a48741c40038821fe3    1858
#
# ...

# %%
for col in hanks3.columns: 
    print(col)
# Out:
# character
# credit_id
# id
# video
# vote_count
# backdrop_path
# genre_ids
# popularity
# title
# vote_average
# overview

# %%
for col in hanks2.columns: 
    print(col)
# Out:
# Title
# Year
# Rated
# Released
# Runtime
# Genre
# Director
# Writer
# Actors
# Plot
# Language
# Country
# Awards
# Ratings
# Metascore
# imdbRating
# imdbVotes
# imdbID
# Type
# Production

# %%
hanks_TMDB
-
character varchar
credit_id varchar
id int
video varchar
vote_count int
backdrop_path varchar
genre_ids int
popularity int
title PK varchar
vote_average int
overview varchar
