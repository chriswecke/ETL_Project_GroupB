# %%
import pandas as pd
import requests
import json
from config import tmdb_key

# %%
# New Dependency! Use this to pretty print the JSON
# https://docs.python.org/3/library/pprint.html
from pprint import pprint

# %%
# Note that the ?t= is a query param for the t-itle of the
# movie we want to search for.
url = "https://api.themoviedb.org/3/person/"
api_key = "?api_key=" + "616f37083b353fd1cb48fc4d07187d48"
language = "&language=en-US"
print(api_key)
# Out:
# ?api_key=616f37083b353fd1cb48fc4d07187d48

# %%
# Performing a GET request similar to the one we executed
# earlier
actor_id = "31" #Manually looked up Tom Hanks ID

response = requests.get(url + actor_id + "/movie_credits" + api_key + language).json()
#print(url + actor_id + api_key + language)
#response = requests.get("https://api.themoviedb.org/3/person/31?api_key=616f37083b353fd1cb48fc4d07187d48")

# %%
# Converting the response to JSON, and printing the result.
movie_credits = response
pprint(movie_credits)
# Out:
# {'cast': [{'adult': False,
#            'backdrop_path': '/7c9UVPPiTPltouxRVY6N9uugaVA.jpg',
#            'character': 'Forrest Gump',
#            'credit_id': '52fe420ec3a36847f800074f',
#            'genre_ids': [35, 18, 10749],
#            'id': 13,
#            'original_language': 'en',
#            'original_title': 'Forrest Gump',
#            'overview': 'A man with a low IQ has accomplished great things in '
#                        'his life and been present during significant historic '
#                        'events—in each case, far exceeding what anyone '
#                        'imagined he could do. But despite all he has achieved, '
#                        'his one true love eludes him.',
#            'popularity': 43.096,
#            'poster_path': '/clolk7rB5lAjs41SD0Vt6IXYLMm.jpg',
#            'release_date': '1994-07-06',
#            'title': 'Forrest Gump',
#            'video': False,
#            'vote_average': 8.5,
# ...

# %%
df = pd.json_normalize(movie_credits)
df.to_csv('Movie_Credits.csv',  header=True)

# %%
# Print a few keys from the response JSON.
print(f"Movie was directed by {data['Director']}.")
print(f"Movie was released in {data['Country']}.")
# Out:
# Movie was directed by James Cameron.
# Movie was released in USA, UK.

# %%
response =requests.get("https://api.themoviedb.org/3/genre/movie/list?api_key=616f37083b353fd1cb48fc4d07187d48&language=en-US")

# %%
genres = response.json()
pprint(genres)
# Out:
# {'genres': [{'id': 28, 'name': 'Action'},
#             {'id': 12, 'name': 'Adventure'},
#             {'id': 16, 'name': 'Animation'},
#             {'id': 35, 'name': 'Comedy'},
#             {'id': 80, 'name': 'Crime'},
#             {'id': 99, 'name': 'Documentary'},
#             {'id': 18, 'name': 'Drama'},
#             {'id': 10751, 'name': 'Family'},
#             {'id': 14, 'name': 'Fantasy'},
#             {'id': 36, 'name': 'History'},
#             {'id': 27, 'name': 'Horror'},
#             {'id': 10402, 'name': 'Music'},
#             {'id': 9648, 'name': 'Mystery'},
#             {'id': 10749, 'name': 'Romance'},
#             {'id': 878, 'name': 'Science Fiction'},
#             {'id': 10770, 'name': 'TV Movie'},
#             {'id': 53, 'name': 'Thriller'},
#             {'id': 10752, 'name': 'War'},
#             {'id': 37, 'name': 'Western'}]}
